# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
plt.plot(np.arange(10),np.arange(10))

# %%
x = []
y = []
l1 = [(100.0, 0.0),
 (80.901699437494742, 58.778525229247315),
 (30.901699437494745, 95.10565162951535),
 (-30.901699437494734, 95.105651629515364),
 (-80.901699437494727, 58.778525229247322),
 (-100.0, 1.2246467991473532e-14)]

for i, j in l1:
    x.append(i)
    y.append(j)

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
